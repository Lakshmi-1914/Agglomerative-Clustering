# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmi-1914/Agglomerative-Clustering/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
conversation_data = {
    'hello' : " hi there how can i help you today?",
    "hi" : 'hello ! how can i help you?',
    "how are you": "I'm just a bot, but I'm doing great! how about you?",
    "what is computer vision" : "computer vision is the field of AI that allows comoputer",
    "what is ai" : "Ai stands for artifial intelligance",
}

# %%
def sample_chat(user_input,chat_history=[]):
  user_input_lower = user_input.lower()
  response = None
  for key in conversation_data:
    if key in user_input_lower:
      response = conversation_data[key]
      break
  if not response:
    response = "sorry,I dont't understand that. can you something else?"
  chat_history.append(("you", user_input))
  chat_history.append(("bot", response))
  return response,chat_history

# %%
print("welcome to mini conversational API")
print("type exit or 'quit' to end the chat.\n")

chat_history = []

while True:
  user_input = input("you:")
  if user_input.lower() in ["exit","quit"]:
    print("chat ended,goodbye!")
    break

  bot_response, chat_history = sample_chat(user_input,chat_history)
  print("Bot:",bot_response)
# Out:
# welcome to mini conversational API
# type exit or 'quit' to end the chat.
#
# you:hello
# Bot:  hi there how can i help you today?
# you:hi
# Bot: hello ! how can i help you?
